# %% [markdown]
# <a href="https://colab.research.google.com/github/marklinista-HO/challenge1-data-science-latam/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #RETO:  A L U R A  S T O R E

# %% [markdown]
# #Importación de datos

# %%
#  Extracción de datos de las 4 tiendas y asignación de DataFrame a cada tienda
import pandas as pd

url1 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(url1)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# %% [markdown]
# REVISIÓN DE LOS DATAFRAMES

# %%
# comprobando los DataFrame y estudiando los datos de Tienda 1
print('Tienda 1')
print(f'Filas: {tienda1.shape[0]} Columnas: {tienda1.shape[1]} ')
print(tienda1.info())
tienda1.head(2)
# Out:
# Tienda 1
# Filas: 2359 Columnas: 12
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB
# None
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   8  4.60971 -74.08175
# 1  Tarjeta de crédito                   4  6.25184 -75.56359

# %%
# comprobando los DataFrame y estudiando los datos de Tienda 2
print('Tienda 2')
print(f'Filas: {tienda2.shape[0]} Columnas: {tienda2.shape[1]} ')
print(tienda2.info())
tienda2.tail(2)
# Out:
# Tienda 2
# Filas: 2359 Columnas: 12
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB
# None
#        Producto Categoría del Producto     Precio  Costo de envío  \
# 2357  Iphone 15           Electrónicos  2224300.0        116600.0
# 2358  Bicicleta   Deportes y diversión   551000.0         27500.0
#
#      Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 2357      21/04/2022  Juan Fernandez        Medellín             5
# 2358      03/09/2022   Maria Alfonso        Medellín             4
#
#           Método de pago  Cantidad de cuotas      lat       lon
# 2357  Tarjeta de crédito                   2  6.25184 -75.56359
# 2358  Tarjeta de crédito                   1  6.25184 -75.56359

# %%
# comprobando los DataFrame y estudiando los datos de Tienda 3
print('Tienda 3')
print(f'Filas: {tienda3.shape[0]} Columnas: {tienda3.shape[1]} ')
print(tienda3.info())
tienda3.head(2)
# Out:
# Tienda 3
# Filas: 2359 Columnas: 12
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB
# None
#            Producto Categoría del Producto     Precio  Costo de envío  \
# 0  Secadora de ropa      Electrodomésticos  1285100.0         66600.0
# 1     Mesa de noche                Muebles   290100.0         13600.0
#
#   Fecha de Compra       Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021  Camila Rivera     Santa Marta             4
# 1      10/02/2021  Maria Alfonso            Cali             3
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# 1  Tarjeta de crédito                   1   3.43722 -76.52250

# %%
# comprobando los DataFrame y estudiando los datos de Tienda 4
print('Tienda 4')
print(f'Filas: {tienda4.shape[0]} Columnas: {tienda4.shape[1]} ')
print(tienda4.info())
tienda4.tail(2)
# Out:
# Tienda 4
# Filas: 2358 Columnas: 12
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2358 non-null   object
#  1   Categoría del Producto  2358 non-null   object
#  2   Precio                  2358 non-null   float64
#  3   Costo de envío          2358 non-null   float64
#  4   Fecha de Compra         2358 non-null   object
#  5   Vendedor                2358 non-null   object
#  6   Lugar de Compra         2358 non-null   object
#  7   Calificación            2358 non-null   int64
#  8   Método de pago          2358 non-null   object
#  9   Cantidad de cuotas      2358 non-null   int64
#  10  lat                     2358 non-null   float64
#  11  lon                     2358 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.2+ KB
# None
#                 Producto   Categoría del Producto    Precio  Costo de envío  \
# 2356        Set de ollas  Artículos para el hogar  151800.0          8300.0
# 2357  Cuerda para saltar     Deportes y diversión   11200.0          1300.0
#
#      Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 2356      15/06/2020  Blanca Ramirez            Cali             5
# 2357      17/11/2021   Felipe Santos          Bogotá             5
#
#           Método de pago  Cantidad de cuotas      lat       lon
# 2356  Tarjeta de crédito                   1  3.43722 -76.52250
# 2357  Tarjeta de crédito                   1  4.60971 -74.08175

# %% [markdown]
# **NOTA:   NO  HAY  VALORES  NULOS**

# %% [markdown]
# ###Estructura de datos:
# El conjunto de datos incluye la siguiente información:
#
# Producto y Categoría: Artículos vendidos y sus calificaciones.
#
# Precio y Envío: Valores de venta y costos asociados.
#
# Fecha y ubicación de compra: Información temporal y geográfica.
#
# Evaluación de compra: Comentarios de clientes.
#
# Tipo de Pago y Cuotas: Métodos utilizados por los clientes.
#
# Coordenadas Geográficas: Ubicación de las transacciones.

# %%
tienda1.columns
#  NOTA:  mismas columnas en todos los dataframes
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
tienda1.dtypes
# Out:
# Producto                   object
# Categoría del Producto     object
# Precio                    float64
# Costo de envío            float64
# Fecha de Compra            object
# Vendedor                   object
# Lugar de Compra            object
# Calificación                int64
# Método de pago             object
# Cantidad de cuotas          int64
# lat                       float64
# lon                       float64
# dtype: object

# %% [markdown]
# CONCLUSIÓN:  NO  hay  que  manipular  datos  para  corrección.

# %% [markdown]
# # 1.Análisis de facturación

# %%
#  Ingreso total por cada tienda:
Ventas_tienda_1 = tienda1['Precio'].sum()
Ventas_tienda_2 = tienda2['Precio'].sum()
Ventas_tienda_3 = tienda3['Precio'].sum()
Ventas_tienda_4 = tienda4['Precio'].sum()


#  Presentar ventas por tienda
print('Ingreso total por cada tienda:')
print(f'Ventas tienda 1: {Ventas_tienda_1:,.2f}' )
print(f'Ventas tienda 2: {Ventas_tienda_2:,.2f}' )
print(f'Ventas tienda 3: {Ventas_tienda_3:,.2f}')
print(f'Ventas tienda 4: {Ventas_tienda_4:,.2f}')

#  Venta total de las 4 tiendas
Venta_total = Ventas_tienda_1 + Ventas_tienda_2 + Ventas_tienda_3 + Ventas_tienda_4
print()
print(f'Ventas total de las 4 tiendas: {Venta_total:,.2f}')
# Out:
# Ingreso total por cada tienda:
# Ventas tienda 1: 1,150,880,400.00
# Ventas tienda 2: 1,116,343,500.00
# Ventas tienda 3: 1,098,019,600.00
# Ventas tienda 4: 1,038,375,700.00
#
# Ventas total de las 4 tiendas: 4,403,619,200.00

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#  Graficando ventas de las tiendas
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
ventas_tiendas = [Ventas_tienda_1, Ventas_tienda_2, Ventas_tienda_3, Ventas_tienda_4,]
colores = ['#FFD07F', '#FDA65D', '#FF8243', '#E26A2C']

plt.figure(figsize=(12,6))

#plt.bar(tiendas, ventas_tiendas, color=colores, edgecolor='black', linewidth=2)
barras = plt.bar(tiendas, ventas_tiendas, color=colores, edgecolor='black', linewidth=1.5)

plt.ylabel('INGRESOS', fontsize=12)
plt.xlabel('TIENDAS', fontsize=12)
plt.title('INGRESO TOTAL DE CADA TIENDA', fontsize=16 )

for barra in barras:
  altura = barra.get_height()
  plt.text(barra.get_x() + barra.get_width()/2., altura, f'${altura/1e6:,.1f}M', ha='center', va='bottom', fontsize=10,)

# %% [markdown]
# # 2.Ventas por categoría

# %% [markdown]
# En este debes calcular la **cantidad de productos** vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
# Inpeccionando las categorías:
tienda1['Categoría del Producto'].unique()
# Out:
# array(['Electrónicos', 'Muebles', 'Juguetes', 'Electrodomésticos',
#        'Artículos para el hogar', 'Deportes y diversión', 'Libros',
#        'Instrumentos musicales'], dtype=object)

# %%
# Ventas totales de cada categoría de Tienda 1:
print('Tienda 1')
print("Ventas por categoría")
tienda1.groupby('Categoría del Producto')['Precio'].sum().sort_values(ascending=False)
# Out:
# Tienda 1
# Ventas por categoría
# Categoría del Producto
# Electrónicos               429493500.0
# Electrodomésticos          363685200.0
# Muebles                    187633700.0
# Instrumentos musicales      91299000.0
# Deportes y diversión        39290000.0
# Juguetes                    17995700.0
# Artículos para el hogar     12698400.0
# Libros                       8784900.0
# Name: Precio, dtype: float64

# %%
# Cantidad de PRODUCTOS vendidos por categoría de Tienda 1
print('Tienda 1')
print("Cantidad de Productos vendidos por categoría")
cant_producs1 = tienda1.groupby('Categoría del Producto')['Precio'].count().sort_values(ascending=False)
cant_producs1
# Out:
# Tienda 1
# Cantidad de Productos vendidos por categoría
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: Precio, dtype: int64

# %%
#
plt.figure(figsize=(5,5))
plt.pie(cant_producs1.values, labels=cant_producs1.index, autopct='%1.1f%%',startangle=90)

plt.title('Ventas por categoría de Tienda #1')

plt.show()

# %%
# Cambiando el nombre de la columna "Categoría del Producto" a "Categoría"
tienda1.rename(columns={'Categoría del Producto': 'Categoría'}, inplace=True)
tienda1.sample()
# Out:
#       Producto     Categoría    Precio  Costo de envío Fecha de Compra  \
# 899  Impresora  Electrónicos  280000.0         13100.0      06/07/2022
#
#           Vendedor Lugar de Compra  Calificación      Método de pago  \
# 899  Juliana Costa         Leticia             5  Tarjeta de crédito
#
#      Cantidad de cuotas      lat       lon
# 899                   3 -4.21528 -69.94056

# %%
# comprobando resultado con juguetes y libros
listaq = tienda1.query(' Categoría == "Juguetes"').count()
list(listaq)[1]
# Out:
# 324

# %%
# Ventas totales de cada categoría de Tienda 2:
print('Tienda 2')
print("Ventas por categoría")
tienda2.groupby('Categoría del Producto')['Precio'].sum().sort_values(ascending=False)
# Out:
# Tienda 2
# Ventas por categoría
# Categoría del Producto
# Electrónicos               410831100.0
# Electrodomésticos          348567800.0
# Muebles                    176426300.0
# Instrumentos musicales     104990300.0
# Deportes y diversión        34744500.0
# Juguetes                    15945400.0
# Artículos para el hogar     14746900.0
# Libros                      10091200.0
# Name: Precio, dtype: float64

# %%
# Cantidad de PRODUCTOS vendidos por categoría de Tienda 2
print('Tienda 2')
print("Cantidad de Productos vendidos por categoría")
cant_producs2 = tienda2.groupby('Categoría del Producto')['Precio'].count().sort_values(ascending=False)
cant_producs2
# Out:
# Tienda 2
# Cantidad de Productos vendidos por categoría
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: Precio, dtype: int64

# %%
#cant_producs2.plot()
#plt.bar(tiendas, ventas_tiendas, color=colores, edgecolor='black', linewidth=1.5)


plt.figure(figsize=(5,5))
# Lista de colores:
#pie_colors = ['#711DB0', '#C21292', '#EF4040', '#FFA732', '#F5E965', '#FF9668', '#DB456F', '#A74FAF']

# plt.pie(ven_cat_t1.values, labels=ven_cat_t1.index, autopct='%1.1f%%', shadow=True, startangle=140, colors=pie_colors)
plt.pie(cant_producs2.values, labels=cant_producs2.index, autopct='%1.1f%%',startangle=90)

plt.title('Ventas por categoría de Tienda #2')
#plt.axis('equal')
#plt.tight_layout()
plt.show()

# %%
# Ventas totales de cada categoría de Tienda 3:
print('Tienda 3')
print("Ventas por categoría")
tienda3.groupby('Categoría del Producto')['Precio'].sum().sort_values(ascending=False)
# Out:
# Tienda 3
# Ventas por categoría
# Categoría del Producto
# Electrónicos               410775800.0
# Electrodomésticos          329237900.0
# Muebles                    201072100.0
# Instrumentos musicales      77380900.0
# Deportes y diversión        35593100.0
# Juguetes                    19401100.0
# Artículos para el hogar     15060000.0
# Libros                       9498700.0
# Name: Precio, dtype: float64

# %%
# Cantidad de PRODUCTOS vendidos por categoría de Tienda 3
print('Tienda 3')
print("Cantidad de Productos vendidos por categoría")
cant_producs3 = tienda3.groupby('Categoría del Producto')['Precio'].count().sort_values(ascending=False)
cant_producs3
# Out:
# Tienda 3
# Cantidad de Productos vendidos por categoría
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Artículos para el hogar    177
# Instrumentos musicales     177
# Name: Precio, dtype: int64

# %%
#
plt.figure(figsize=(5,5))
plt.pie(cant_producs3.values, labels=cant_producs3.index, autopct='%1.1f%%',startangle=90)

plt.title('Ventas por categoría de Tienda #3')

plt.show()

# %%
# Ventas totales de cada categoría de Tienda 4:
print('Tienda 4')
print("Ventas por categoría")
tienda4.groupby('Categoría del Producto')['Precio'].sum().sort_values(ascending=False)
# Out:
# Tienda 4
# Ventas por categoría
# Categoría del Producto
# Electrónicos               409476100.0
# Electrodomésticos          283260200.0
# Muebles                    192528900.0
# Instrumentos musicales      75102400.0
# Deportes y diversión        33350100.0
# Juguetes                    20262200.0
# Artículos para el hogar     15074500.0
# Libros                       9321300.0
# Name: Precio, dtype: float64

# %%
# Cantidad de PRODUCTOS vendidos por categoría de Tienda 4
print('Tienda 4')
print("Cantidad de Productos vendidos por categoría")
cant_producs4 = tienda4.groupby('Categoría del Producto')['Precio'].count().sort_values(ascending=False)
cant_producs4
# Out:
# Tienda 4
# Cantidad de Productos vendidos por categoría
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: Precio, dtype: int64

# %%
#
plt.figure(figsize=(5,5))
plt.pie(cant_producs4.values, labels=cant_producs4.index, autopct='%1.1f%%',startangle=90)

plt.title('Ventas por categoría de Tienda #4')

plt.show()

# %% [markdown]
# # 3.Calificación promedio de la tienda

# %% [markdown]
# En este paso, debes calcular las calificaciones promedio de los clientes para cada tienda. El objetivo es **conocer la satisfacción del cliente con los productos vendidos**.

# %%
#   Promedio de satisfacción del cliente con los productos vendidos de Tienda 1
print('Tienda 1')
cant_calific_1 = tienda1['Calificación'].count()
print('Cantidad de calificaciones:', cant_calific_1)
suma_calific_1 = tienda1['Calificación'].sum()
print('Suma total de calificaciones:',suma_calific_1)
promedio_calific_1 = suma_calific_1 / cant_calific_1
print(f'Calificación promedio de Tienda 1 es de {promedio_calific_1:,.2f}')
# Out:
# Tienda 1
# Cantidad de calificaciones: 2359
# Suma total de calificaciones: 9381
# Calificación promedio de Tienda 1 es de 3.98

# %%
#   Promedio de satisfacción del cliente con los productos vendidos de Tienda 2
print('Tienda 2')
cant_calific_2 = tienda2['Calificación'].count()
print('Cantidad de calificaciones:', cant_calific_2)
suma_calific_2 = tienda2['Calificación'].sum()
print('Suma total de calificaciones:',suma_calific_2)
promedio_calific_2 = suma_calific_2 / cant_calific_2
print(f'Calificación promedio de Tienda 2 es de {promedio_calific_2:,.2f}')
# Out:
# Tienda 2
# Cantidad de calificaciones: 2359
# Suma total de calificaciones: 9524
# Calificación promedio de Tienda 2 es de 4.04

# %%
#   Promedio de satisfacción del cliente con los productos vendidos de Tienda 3
print('Tienda 3')
cant_calific_3 = tienda3['Calificación'].count()
print('Cantidad de calificaciones:', cant_calific_3)
suma_calific_3 = tienda3['Calificación'].sum()
print('Suma total de calificaciones:',suma_calific_3)
promedio_calific_3 = suma_calific_3 / cant_calific_3
print(f'Calificación promedio de Tienda 3 es de {promedio_calific_3:,.2f}')
# Out:
# Tienda 3
# Cantidad de calificaciones: 2359
# Suma total de calificaciones: 9550
# Calificación promedio de Tienda 3 es de 4.05

# %%
#   Promedio de satisfacción del cliente con los productos vendidos de Tienda 4
print('Tienda 4')
cant_calific_4 = tienda4['Calificación'].count()
print('Cantidad de calificaciones:', cant_calific_4)
suma_calific_4 = tienda4['Calificación'].sum()
print('Suma total de calificaciones:',suma_calific_4)
promedio_calific_4 = suma_calific_4 / cant_calific_4
print(f'Calificación promedio de Tienda 4 es de {promedio_calific_4:,.2f}')
# Out:
# Tienda 4
# Cantidad de calificaciones: 2358
# Suma total de calificaciones: 9422
# Calificación promedio de Tienda 4 es de 4.00

# %%
#   Promedio de satisfacción del cliente con los productos vendidos en las 4 tiendas
#   Usando .mean  para  corroborrar

def calificacion_tienda(tienda, numero):
    promedio = tienda['Calificación'].mean()
    print(f"Calificación promedio en Tienda {numero}: {promedio:.2f}")

# Generando resultados de cada tienda:
calificacion_tienda(tienda1, 1)
calificacion_tienda(tienda2, 2)
calificacion_tienda(tienda3, 3)
calificacion_tienda(tienda4, 4)
# Out:
# Calificación promedio en Tienda 1: 3.98
# Calificación promedio en Tienda 2: 4.04
# Calificación promedio en Tienda 3: 4.05
# Calificación promedio en Tienda 4: 4.00

# %%
#  Graficando evaluaciones de las tiendas
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

calific_tiendas = [promedio_calific_1, promedio_calific_2, promedio_calific_3, promedio_calific_4]

# ventas_tiendas = [Ventas_tienda_1, Ventas_tienda_2, Ventas_tienda_3, Ventas_tienda_4,]
colores = ['#FFD07F', '#FDA65D', '#FF8243', '#E26A2C']

plt.figure(figsize=(12,6))

#barras = plt.bar(tiendas, calific_tiendas, color=colores, edgecolor='black', linewidth=1.5)
barras = plt.bar(tiendas, calific_tiendas, edgecolor='black', linewidth=1.5)

plt.ylabel('CALIFICACION', fontsize=12)
plt.xlabel('TIENDAS', fontsize=12)
plt.title('CALIFICACION POR CLIENTES DE CADA TIENDA', fontsize=16 )

for barra in barras:
  altura = barra.get_height()
  plt.text(barra.get_x() + barra.get_width()/2., altura, f'{altura:,.2f}', ha='center', va='bottom', fontsize=10,)

# %% [markdown]
# # 4.Productos más y menos vendidos

# %% [markdown]
# En este paso, debes identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %%
# Cantidad de PRODUCTOS vendidos por categoría de Tienda 1
print('Tienda 1')
print("Cantidad de Productos vendidos por categoría")

df_ventas_categoria1 = tienda1.groupby('Categoría')['Precio'].count().sort_values()

df_ventas_categoria1.plot(kind='barh',figsize=(5,6),color='green',title='TIENDA 1\nProductos Vendidos',xlabel='Cantidad');
# Out:
# Tienda 1
# Cantidad de Productos vendidos por categoría

# %%
# Cantidad de PRODUCTOS vendidos por categoría de Tienda 2
print('Tienda 2')
print("Cantidad de Productos vendidos por categoría")

df_ventas_categoria2 = tienda2.groupby('Categoría del Producto')['Precio'].count().sort_values()

df_ventas_categoria2.plot(kind='barh',figsize=(5,6),color='green',title='TIENDA 2\nProductos Vendidos',xlabel='Cantidad');
# Out:
# Tienda 2
# Cantidad de Productos vendidos por categoría

# %%
# Cantidad de PRODUCTOS vendidos por categoría de Tienda 3
print('Tienda 3')
print("Cantidad de Productos vendidos por categoría")

df_ventas_categoria3 = tienda3.groupby('Categoría del Producto')['Precio'].count().sort_values()

df_ventas_categoria3.plot(kind='barh',figsize=(5,6),color='green',title='TIENDA 3\nProductos Vendidos',xlabel='Cantidad');
# Out:
# Tienda 3
# Cantidad de Productos vendidos por categoría

# %%
# Cantidad de PRODUCTOS vendidos por categoría de Tienda 4
print('Tienda 4')
print("Cantidad de Productos vendidos por categoría")

df_ventas_categoria4 = tienda4.groupby('Categoría del Producto')['Precio'].count().sort_values()

df_ventas_categoria4.plot(kind='barh',figsize=(5,6),color='green',title='TIENDA 4\nProductos Vendidos',xlabel='Cantidad');
# Out:
# Tienda 4
# Cantidad de Productos vendidos por categoría

# %% [markdown]
# # 5.Envío promedio por tienda

# %% [markdown]
# En este paso, debes calcular el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda.  Sabiendo que el cliente paga el envío.

# %%
#  Calculando el promedio de costos de envío usando totales de columna
#  TIENDA 1
cant_costo_envios_1 = tienda1['Costo de envío'].count()
cant_costo_envios_1
tot_costo_envios_1 = tienda1['Costo de envío'].sum()
tot_costo_envios_1
promedio_costo_envios_1 = tot_costo_envios_1 / cant_costo_envios_1
print(f'Promedio de costos de envío de Tienda 1: {promedio_costo_envios_1:,.2f}')

#  TIENDA 2
cant_costo_envios_2 = tienda2['Costo de envío'].count()
cant_costo_envios_2
tot_costo_envios_2 = tienda2['Costo de envío'].sum()
tot_costo_envios_2
promedio_costo_envios_2 = tot_costo_envios_2 / cant_costo_envios_2
print(f'Promedio de costos de envío de Tienda 2: {promedio_costo_envios_2:,.2f}')

#  TIENDA 3
cant_costo_envios_3 = tienda3['Costo de envío'].count()
cant_costo_envios_3
tot_costo_envios_3 = tienda3['Costo de envío'].sum()
tot_costo_envios_3
promedio_costo_envios_3 = tot_costo_envios_3 / cant_costo_envios_3
print(f'Promedio de costos de envío de Tienda 3: {promedio_costo_envios_3:,.2f}')

#  TIENDA 2
cant_costo_envios_4 = tienda4['Costo de envío'].count()
cant_costo_envios_4
tot_costo_envios_4 = tienda4['Costo de envío'].sum()
tot_costo_envios_4
promedio_costo_envios_4 = tot_costo_envios_4 / cant_costo_envios_4
print(f'Promedio de costos de envío de Tienda 4: {promedio_costo_envios_4:,.2f}')
# Out:
# Promedio de costos de envío de Tienda 1: 26,018.61
# Promedio de costos de envío de Tienda 2: 25,216.24
# Promedio de costos de envío de Tienda 3: 24,805.68
# Promedio de costos de envío de Tienda 4: 23,459.46

# %%
#  Confirmando valor con .describe
tienda1['Costo de envío'].describe()['mean']
print(f'Promedio de costos de envío de Tienda 1: {tienda1['Costo de envío'].describe()['mean']:,.2f}')

print(f'Promedio de costos de envío de Tienda 2: {tienda2['Costo de envío'].describe()['mean']:,.2f}')

print(f'Promedio de costos de envío de Tienda 3: {tienda3['Costo de envío'].describe()['mean']:,.2f}')

print(f'Promedio de costos de envío de Tienda 4: {tienda4['Costo de envío'].describe()['mean']:,.2f}')
# Out:
# Promedio de costos de envío de Tienda 1: 26,018.61
# Promedio de costos de envío de Tienda 2: 25,216.24
# Promedio de costos de envío de Tienda 3: 24,805.68
# Promedio de costos de envío de Tienda 4: 23,459.46

# %% [markdown]
# # 6.Datos y graficos para análisis

# %%
#  Graficando ventas de las tiendas
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
ventas_tiendas = [Ventas_tienda_1, Ventas_tienda_2, Ventas_tienda_3, Ventas_tienda_4,]
colores = ['#FFD07F', '#FDA65D', '#FF8243', 'red']

plt.figure(figsize=(12,6))

barras = plt.bar(tiendas, ventas_tiendas, color=colores, edgecolor='black', linewidth=1.5)

plt.ylabel('INGRESOS', fontsize=12)
plt.xlabel('TIENDAS', fontsize=12)
plt.title('INGRESO TOTAL DE CADA TIENDA', fontsize=16 )

for barra in barras:
  altura = barra.get_height()
  plt.text(barra.get_x() + barra.get_width()/2., altura, f'${altura/1e6:,.1f}M', ha='center', va='bottom', fontsize=10,)

# %% [markdown]
# Graficar tendencia de ventas mensuales:

# %%
# convertir fechas a  datetime
tienda1['Fecha de Compra'] = pd.to_datetime(tienda1['Fecha de Compra'], dayfirst=True)
tienda2['Fecha de Compra'] = pd.to_datetime(tienda2['Fecha de Compra'], dayfirst=True)
tienda3['Fecha de Compra'] = pd.to_datetime(tienda3['Fecha de Compra'], dayfirst=True)
tienda4['Fecha de Compra'] = pd.to_datetime(tienda4['Fecha de Compra'], dayfirst=True)

# %%
# Calcular ventas mensuales en cada tienda
# Agrupar por fecha y sumar precio
venta_mensual_1 = tienda1.groupby([tienda1['Fecha de Compra'].dt.to_period('M')])['Precio'].sum().reset_index()
venta_mensual_2 = tienda1.groupby([tienda2['Fecha de Compra'].dt.to_period('M')])['Precio'].sum().reset_index()
venta_mensual_3 = tienda1.groupby([tienda3['Fecha de Compra'].dt.to_period('M')])['Precio'].sum().reset_index()
venta_mensual_4 = tienda1.groupby([tienda4['Fecha de Compra'].dt.to_period('M')])['Precio'].sum().reset_index()
venta_mensual_3.head(1)
# Out:
#   Fecha de Compra      Precio
# 0         2020-01  34923700.0

# %%
#  Crear columna Tienda ID
venta_mensual_1['Tienda_ID'] = 'Tienda 1'
venta_mensual_2['Tienda_ID'] = 'Tienda 2'
venta_mensual_3['Tienda_ID'] = 'Tienda 3'
venta_mensual_4['Tienda_ID'] = 'Tienda 4'
#
hd_todas = pd.concat([venta_mensual_1,venta_mensual_2,venta_mensual_3,venta_mensual_4], ignore_index=True)
hd_todas.head(2)
# Out:
#   Fecha de Compra      Precio Tienda_ID
# 0         2020-01  33084300.0  Tienda 1
# 1         2020-02  40054000.0  Tienda 1

# %%
#  Vamos a crea tabla  ventas_mensuales  de nuestro DataFrame  meses
#  Que tenga los meses x las tiendas.  Y en datos, la cantidad vendida de productos
#  Usamos el  picot_table  para crear una tabla dinámica
#  El índice son los  meses
#  Las cols  son las tiendas
#  Los valores son la cantidad vendida de productos
#  sum() es la función de agregación
#  sort = False     para que NO  se reordene al crear la tabla.
ventas_mensuales = hd_todas.pivot_table(index=hd_todas.Tienda_ID, columns='Fecha de Compra', values='Precio', aggfunc='sum', sort=False)
ventas_mensuales = ventas_mensuales.T
ventas_mensuales
# Out:
# Tienda_ID          Tienda 1    Tienda 2    Tienda 3    Tienda 4
# Fecha de Compra
# 2020-01          33084300.0  33639300.0  34923700.0  26957900.0
# 2020-02          40054000.0  24800200.0  32413800.0  34687500.0
# 2020-03          31562300.0  40117900.0  27667600.0  41707200.0
# 2020-04          33666100.0  43898800.0  24676800.0  41054900.0
# 2020-05          38582900.0  26058500.0  24726500.0  30627900.0
# 2020-06          26296700.0  27088200.0  22517600.0  20155000.0
# 2020-07          35085500.0  29668900.0  31691600.0  28524500.0
# 2020-08          31126500.0  19267300.0  21392800.0  31365100.0
# 2020-09          30243800.0  24242500.0  36340000.0  25764600.0
# 2020-10          21134300.0  41775500.0  23782300.0  10776000.0
# 2020-11          19869300.0  25522700.0  23161600.0  40787100.0
# 2020-12          28227500.0  25708700.0  41923100.0  27073500.0
# 2021-01          25554000.0  24346700.0  27093600.0  21152800.0
# 2021-02          32617700.0  14907600.0  18288300.0  24701200.0
# 2021-03          29348500.0  23543300.0  23267400.0  35653800.0
# 2021-04          22637300.0  35328200.0  28328200.0  44342100.0
# 2021-05          27802100.0  33969200.0  22732800.0  26178100.0
# 2021-06          30810100.0  31011300.0  44377500.0  24795600.0
# 2021-07          36878000.0  37065100.0  30638700.0  39818800.0
# 2021-08          34870300.0  23440800.0  42115700.0  27646600.0
# 2021-09          44571100.0  28592000.0  16513000.0  26985700.0
# 2021-10          27536000.0  26313000.0  45326100.0  33078100.0
# 2021-11          26171200.0  26957000.0  51651800.0  39662200.0
# 2021-12          23324500.0  30218500.0  29868600.0  28135100.0
# 2022-01          26233300.0  24882400.0  26025500.0  35756800.0
# 2022-02          27799900.0  20439900.0  25503200.0  37672300.0
# 2022-03          25366700.0  30683500.0  20742500.0  42660400.0
# 2022-04          22384400.0  38533700.0  14202000.0  32339200.0
# 2022-05          25097800.0  30265400.0  28982200.0  25236300.0
# 2022-06          24984500.0  32371400.0  38734200.0  17353900.0
# 2022-07          27251400.0  31645800.0  28249600.0  15930000.0
# 2022-08          27796000.0  32918000.0  24941300.0  35497600.0
# 2022-09          37111000.0  31263800.0  36172900.0  23755700.0
# 2022-10          14682000.0  30539800.0  24116400.0  26231700.0
# 2022-11          23656300.0  27853400.0  30066300.0  20662500.0
# 2022-12          34202300.0  24241600.0  23335300.0  39874400.0
# 2023-01          28930100.0  28901300.0  38897600.0  12753700.0
# 2023-02          37227700.0  32887000.0  23084700.0  30575200.0
# 2023-03          37103000.0  35972200.0  42407600.0  22754400.0

# %%
#  tendencia de ventas a lo largo de los meses de cada tienda.
ventas_mensuales.plot(ylabel='Ventas',title = 'Ventas mensuales',figsize=(12, 6));

plt.title('Tendencia de ventas por tienda', fontsize=15)
plt.ylabel('Monto de ventas Mensuales (USD)')
#plt.xlabel('Mes')

plt.grid(True)
plt.tight_layout()

plt.show()

# %%
# Ventas menuales de cada tienda:
venta_mensual_1.plot(xlabel='Tiempo',ylabel='Ventas',title = 'Ventas mensuales Tienda 1');
venta_mensual_2.plot(xlabel='Tiempo',ylabel='Ventas',title = 'Ventas mensuales Tienda 2');
venta_mensual_3.plot(xlabel='Tiempo',ylabel='Ventas',title = 'Ventas mensuales Tienda 3');
venta_mensual_4.plot(xlabel='Tiempo',ylabel='Ventas',title = 'Ventas mensuales Tienda 4');

# %% [markdown]
# # 7.Informe de rendimiento de las tiendas
#
# Basándonos en el Ingreso, el rendimiento y la calidad de las ventas, se hará una recomendación de la tienda que según los datos es la que tiene resultados menos lucrativos.
# ---
# ---

# %% [markdown]
# **Estimado Sr. Juan:**
#
# Este informe fue elaborado para ayudarlo a decidir qué tienda de su cadena Alura Store debe vender para iniciar un nuevo emprendimiento. Se analizarán datos de ventas, rendimiento y reseñas de las 4 tiendas de Alura Store. El objetivo es identificar la tienda menos eficiente y así presentar una recomendación final basada en los datos.
#
# **A continuación le presento los resultados del análisis de las ventas de las cuatro tiendas:**
#
#
# 1) Al hacer el análisis de facturación, se pudo apreciar en los resultados y en la gráfica que que la tienda 4 es la que acumula menor ingreso total durante estos últimos 3 años.
#
# ![image.png](data:image/png;base64,...)
#
#
#
# 2) En la calificación de los clientes, los resultados son muy parejos, lo que indica que todas las tiendas tienen el mismo nivel de satisfacción para los clientes y no es un factor a considerar en el rendimiento de las tiendas.
#
# ![image.png](data:image/png;base64,...)
#
# 3) En las gráficas de ventas mensuales, se puede ver que la Tienda 4 es la única que ha tenido tendencia hacia la baja en los últimos meses, lo que es consistentes con lo mostrado en las ventas totales.  reforzando su posición como la de menor rendimiento histórico.
# Las otras tiendas muestran fluctuaciones al alza o estabilidad.  El que la tienda 4 sea la única a la baja puede ser indicativo de un deterioro operativo reciente y sugiere que sus problemas son estructurales.
#
# ![image.png](data:image/png;base64,...)
#
# 4) Los picos más bajos de ventas mensuales las a demostrado
# la tienda 4.
#
#
#
#
#
# #**Conclusión y recomendación:**
#
#
# La **Tienda 4** no sólo tiene el volumen y lucro más bajos que hemos visto en los gráficos 1 y 2, sino que su rendimiento está empeorando activamente como vimos en el gráfico número 3, lo que justifica la recomendación de vender o reestructurar esta tienda.
